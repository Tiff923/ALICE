# %% [markdown]
# # Literature (NER)
# State of NER:
# - http://nlpprogress.com/english/named_entity_recognition.html
# - https://arxiv.org/pdf/1812.09449.pdf
#
# ## Flair NLP
# - Comparison of NER: https://towardsdatascience.com/benchmark-ner-algorithm-d4ab01b2d4c3
# - Documentation: https://github.com/flairNLP/flair/blob/master/resources/docs/TUTORIAL_2_TAGGING.md
# - Flair vs Spacy: https://medium.com/@sapphireduffy/is-flair-a-suitable-alternative-to-spacy-6f55192bfb01

# %%
from utils import extract_text, normalize_corpus
import pandas as pd
import numpy as np
import nltk
import spacy
from spacy import displacy
import textract
import re

# %%
nlp = spacy.load("en_core_web_sm")

# %%
# def named_entity_recognition():
#     text = "LONDON \u2014 The sound of crisply struck golf balls could be heard in England for the first time in nearly two months as courses reopened Wednesday, part of a modest easing of coronavirus lockdown restrictions.  But delight at the resumption of some recreation was mixed with anxiety among commuters and transit staff as people began to return to workplaces. After seven weeks of lockdown, people in England were allowed to exercise more than once a day and with one person from outside their household, provided they remained 2 meters (around 6.5 feet) apart. Other sporting activities, such as tennis, fishing, boating and lake swimming, also resumed. David Baillie, the pro at Dulwich & Sydenham Hill Golf Club in southeast London, said 170 members booked tee-off times to play in pairs on Wednesday and that all slots are taken through Tuesday.  \u201cIt's gone swimmingly well,\u201d he said. Stores selling gardening supplies reported busy trade as they reopened, and potential home buyers were told they could once again visit properties. And, importantly in the context of getting the ailing British economy back on its feet, people who can't work from home, such as those in construction and manufacturing, were being encouraged by the government to return to work if they can do so safely. Some construction sites have resumed work, and automaker Ford announced plans to restart production at two factories in the U.K. The easing of restrictions applies only in England. The semi-autonomous governments of Scotland, Wales and Northern Ireland are going more slowly and sticking with the \u201cStay Home\u201d message, partly because the epidemic is at different stages in different parts of the country, Johnson justified the modest easing on the grounds that Britain has passed the peak of the outbreak, with deaths and new infections in decline. The U.K. has officially recorded the most coronavirus-related deaths in Europe, more than 33,000, a toll second only to the United States. The government is trying to defeat the outbreak while gradually restarting an economy that shrank by 2% in the first quarter of the year, with output falling 5.8% in March, the month everyday life began to shut down. Treasury chief Rishi Sunak said the U.K. was headed for a \"significant recession. But there was confusion about the \u201cback to work\u201d guidance, first announced by U.K. Prime Minister Boris Johnson on Sunday. Critics of Johnson's Conservative government say the changes, spelled out in a 50-page document, are confusing and potentially dangerous. Johnson denied that there had been mixed messaging and told lawmakers that \u201cthe common sense of the British people is shining through.\u201d One of the main concerns centers on how people can travel to work while keeping to social distancing requirements, especially in London, where most commuters use public transit. Transport for London said that in the morning hours up to 10 a.m., the number of passengers on the capital\u2019s subway system was around 7.3% higher than on the same day last week. Carl Moss, 39, traveling to his job as a gardener at St. Thomas\u2019 Hospital in central London, said it's been \u201cbusier today\u201d and that he'd seen \u201cmore office, finance-type people\u201d as well as manual workers. The union that represents train drivers voiced concerns about overcrowding following images on social media showing passengers crowded together on Tube trains and buses. At London's Victoria train and subway station, worker Linda Freitas said she felt \u201canxious and a bit scared\u201d about the prospect of more commuters. A ticket office worker at the station died with COVID-19 last month after being spat at by a man claiming to have the coronavirus. \u201cIf it\u2019s done gradually let\u2019s see, but if it\u2019s too many people then it will be a bit of a problem,\" Freitas said. Meanwhile, Johnson is under fire for his government's handling of an outbreak that has infected more than 200,000 Britons \u2014 including the prime minister, who spent three nights in intensive care last month. On Wednesday, the government announced 600 million pounds ($735 million) in funding to stop coronavirus infections in nursing homes. But opponents said the money was too late to save thousands of vulnerable residents. More than 8,000 people with the coronavirus died in nursing homes up to the start of May, according to Britain\u2019s Office for National Statistics, and the full figure is likely substantially higher. Keir Starmer, the leader of the opposition Labour Party, accused the government of being lax for releasing people from hospitals into nursing homes earlier in the outbreak without testing them for the coronavirus. Johnson called the situation in care homes \u201ca tragedy\u201d but said the number of infections and deaths was now falling."

#     normalized_corpus = normalize_corpus([text], to_lower=False, to_remove_html=False,
#                      to_remove_accent=True, to_expand_contractions=True,
#                      to_lemmatize=False, to_remove_special=False,
#                      to_remove_stopword=False)
    
    
#     entities = []
#     for sentence in normalized_corpus:
#         temp_entity_name = ''
#         temp_named_entity = None
#         sentence_nlp = nlp(sentence)
#         displacy.render(sentence_nlp, style='ent', jupyter=True)
#         for word in sentence_nlp:
#             term = word.text
#             tag = word.ent_type_
#             if tag:
#                 temp_entity_name = ' '.join([temp_entity_name, term]).strip()
#                 temp_named_entity = (temp_entity_name, tag)
#             else:
#                 if temp_named_entity:
#                     entities.append(temp_named_entity)
#                     temp_entity_name = ''
#                     temp_named_entity = None

# #     return entities
#     print(entities)
#     # Create dataframe
#     entity_df = pd.DataFrame(entities,
#                              columns=['Entity Name', 'Entity Type'])
#     top_entities = (entity_df.groupby(by=['Entity Name', 'Entity Type'])
#                     .size()
#                     .sort_values(ascending=False)
#                     .reset_index().rename(columns={0: 'Frequency'}))
#     print(top_entities)

# %%
# named_entity_recognition()

# %% [markdown]
# # Flair NER

# %%
text = "LONDON \u2014 The sound of crisply struck golf balls could be heard in England for the first time in nearly two months as courses reopened Wednesday, part of a modest easing of coronavirus lockdown restrictions.  But delight at the resumption of some recreation was mixed with anxiety among commuters and transit staff as people began to return to workplaces. After seven weeks of lockdown, people in England were allowed to exercise more than once a day and with one person from outside their household, provided they remained 2 meters (around 6.5 feet) apart. Other sporting activities, such as tennis, fishing, boating and lake swimming, also resumed. David Baillie, the pro at Dulwich & Sydenham Hill Golf Club in southeast London, said 170 members booked tee-off times to play in pairs on Wednesday and that all slots are taken through Tuesday.  \u201cIt's gone swimmingly well,\u201d he said. Stores selling gardening supplies reported busy trade as they reopened, and potential home buyers were told they could once again visit properties. And, importantly in the context of getting the ailing British economy back on its feet, people who can't work from home, such as those in construction and manufacturing, were being encouraged by the government to return to work if they can do so safely. Some construction sites have resumed work, and automaker Ford announced plans to restart production at two factories in the U.K. The easing of restrictions applies only in England. The semi-autonomous governments of Scotland, Wales and Northern Ireland are going more slowly and sticking with the \u201cStay Home\u201d message, partly because the epidemic is at different stages in different parts of the country, Johnson justified the modest easing on the grounds that Britain has passed the peak of the outbreak, with deaths and new infections in decline. The U.K. has officially recorded the most coronavirus-related deaths in Europe, more than 33,000, a toll second only to the United States. The government is trying to defeat the outbreak while gradually restarting an economy that shrank by 2% in the first quarter of the year, with output falling 5.8% in March, the month everyday life began to shut down. Treasury chief Rishi Sunak said the U.K. was headed for a \"significant recession. But there was confusion about the \u201cback to work\u201d guidance, first announced by U.K. Prime Minister Boris Johnson on Sunday. Critics of Johnson's Conservative government say the changes, spelled out in a 50-page document, are confusing and potentially dangerous. Johnson denied that there had been mixed messaging and told lawmakers that \u201cthe common sense of the British people is shining through.\u201d One of the main concerns centers on how people can travel to work while keeping to social distancing requirements, especially in London, where most commuters use public transit. Transport for London said that in the morning hours up to 10 a.m., the number of passengers on the capital\u2019s subway system was around 7.3% higher than on the same day last week. Carl Moss, 39, traveling to his job as a gardener at St. Thomas\u2019 Hospital in central London, said it's been \u201cbusier today\u201d and that he'd seen \u201cmore office, finance-type people\u201d as well as manual workers. The union that represents train drivers voiced concerns about overcrowding following images on social media showing passengers crowded together on Tube trains and buses. At London's Victoria train and subway station, worker Linda Freitas said she felt \u201canxious and a bit scared\u201d about the prospect of more commuters. A ticket office worker at the station died with COVID-19 last month after being spat at by a man claiming to have the coronavirus. \u201cIf it\u2019s done gradually let\u2019s see, but if it\u2019s too many people then it will be a bit of a problem,\" Freitas said. Meanwhile, Johnson is under fire for his government's handling of an outbreak that has infected more than 200,000 Britons \u2014 including the prime minister, who spent three nights in intensive care last month. On Wednesday, the government announced 600 million pounds ($735 million) in funding to stop coronavirus infections in nursing homes. But opponents said the money was too late to save thousands of vulnerable residents. More than 8,000 people with the coronavirus died in nursing homes up to the start of May, according to Britain\u2019s Office for National Statistics, and the full figure is likely substantially higher. Keir Starmer, the leader of the opposition Labour Party, accused the government of being lax for releasing people from hospitals into nursing homes earlier in the outbreak without testing them for the coronavirus. Johnson called the situation in care homes \u201ca tragedy\u201d but said the number of infections and deaths was now falling."

text = normalize_corpus([text], to_lower=False, to_remove_html=False,
                 to_remove_accent=True, to_expand_contractions=True,
                 to_lemmatize=False, to_remove_special=False,
                 to_remove_stopword=False)
text = text[0]
text
# Out:
# 'LONDON The sound of crisply struck golf balls could be heard in England for the first time in nearly two months as courses reopened Wednesday, part of a modest easing of coronavirus lockdown restrictions. But delight at the resumption of some recreation was mixed with anxiety among commuters and transit staff as people began to return to workplaces. After seven weeks of lockdown, people in England were allowed to exercise more than once a day and with one person from outside their household, provided they remained 2 meters (around 6.5 feet) apart. Other sporting activities, such as tennis, fishing, boating and lake swimming, also resumed. David Baillie, the pro at Dulwich & Sydenham Hill Golf Club in southeast London, said 170 members booked tee-off times to play in pairs on Wednesday and that all slots are taken through Tuesday. It is gone swimmingly well, he said. Stores selling gardening supplies reported busy trade as they reopened, and potential home buyers were told they could once again visit properties. And, importantly in the context of getting the ailing British economy back on its feet, people who cannot work from home, such as those in construction and manufacturing, were being encouraged by the government to return to work if they can do so safely. Some construction sites have resumed work, and automaker Ford announced plans to restart production at two factories in the U.K. The easing of restrictions applies only in England. The semi-autonomous governments of Scotland, Wales and Northern Ireland are going more slowly and sticking with the Stay Home message, partly because the epidemic is at different stages in different parts of the country, Johnson justified the modest easing on the grounds that Britain has passed the peak of the outbreak, with deaths and new infections in decline. The U.K. has officially recorded the most coronavirus-related deaths in Europe, more than 33,000, a toll second only to the United States. The government is trying to defeat the outbreak while gradually restarting an economy that shrank by 2% in the first quarter of the year, with output falling 5.8% in March, the month everyday life began to shut down. Treasury chief Rishi Sunak said the U.K. was headed for a "significant recession. But there was confusion about the back to work guidance, first announced by U.K. Prime Minister Boris Johnson on Sunday. Critics of Johnsons Conservative government say the changes, spelled out in a 50-page document, are confusing and potentially dangerous. Johnson denied that there had been mixed messaging and told lawmakers that the common sense of the British people is shining through. One of the main concerns centers on how people can travel to work while keeping to social distancing requirements, especially in London, where most commuters use public transit. Transport for London said that in the morning hours up to 10 a.m., the number of passengers on the capitals subway system was around 7.3% higher than on the same day last week. Carl Moss, 39, traveling to his job as a gardener at St. Thomas Hospital in central London, said it is been busier today and that he would seen more office, finance-type people as well as manual workers. The union that represents train drivers voiced concerns about overcrowding following images on social media showing passengers crowded together on Tube trains and buses. At Londons Victoria train and subway station, worker Linda Freitas said she felt anxious and a bit scared about the prospect of more commuters. A ticket office worker at the station died with COVID-19 last month after being spat at by a man claiming to have the coronavirus. If its done gradually lets see, but if its too many people then it will be a bit of a problem," Freitas said. Meanwhile, Johnson is under fire for his governments handling of an outbreak that has infected more than 200,000 Britons including the prime minister, who spent three nights in intensive care last month. On Wednesday, the gover ...

# %%
from flair.data import Sentence
from flair.models import SequenceTagger

# %%
tagger_fast = SequenceTagger.load('ner-ontonotes-fast')
# Out:
# 2020-05-30 13:12:36,333 loading file /Users/SamuelDNinja/.flair/models/en-ner-ontonotes-fast-v0.4.pt

# %%
tagger = SequenceTagger.load('ner-ontonotes')
# Out:
# 2020-05-30 13:12:49,944 loading file /Users/SamuelDNinja/.flair/models/en-ner-ontonotes-v0.4.pt

# %%
from utils import normalize_corpus
import nltk
import spacy
from spacy import displacy
from flair.data import Sentence
from flair.models import SequenceTagger
import sys
from collections import defaultdict

tagger_fast = SequenceTagger.load('ner-ontonotes-fast')

raw = "LONDON \u2014 The sound of crisply struck golf balls could be heard in England for the first time in nearly two months as courses reopened Wednesday, part of a modest easing of coronavirus lockdown restrictions.  But delight at the resumption of some recreation was mixed with anxiety among commuters and transit staff as people began to return to workplaces. After seven weeks of lockdown, people in England were allowed to exercise more than once a day and with one person from outside their household, provided they remained 2 meters (around 6.5 feet) apart. Other sporting activities, such as tennis, fishing, boating and lake swimming, also resumed. David Baillie, the pro at Dulwich & Sydenham Hill Golf Club in southeast London, said 170 members booked tee-off times to play in pairs on Wednesday and that all slots are taken through Tuesday.  \u201cIt's gone swimmingly well,\u201d he said. Stores selling gardening supplies reported busy trade as they reopened, and potential home buyers were told they could once again visit properties. And, importantly in the context of getting the ailing British economy back on its feet, people who can't work from home, such as those in construction and manufacturing, were being encouraged by the government to return to work if they can do so safely. Some construction sites have resumed work, and automaker Ford announced plans to restart production at two factories in the U.K. The easing of restrictions applies only in England. The semi-autonomous governments of Scotland, Wales and Northern Ireland are going more slowly and sticking with the \u201cStay Home\u201d message, partly because the epidemic is at different stages in different parts of the country, Johnson justified the modest easing on the grounds that Britain has passed the peak of the outbreak, with deaths and new infections in decline. The U.K. has officially recorded the most coronavirus-related deaths in Europe, more than 33,000, a toll second only to the United States. The government is trying to defeat the outbreak while gradually restarting an economy that shrank by 2% in the first quarter of the year, with output falling 5.8% in March, the month everyday life began to shut down. Treasury chief Rishi Sunak said the U.K. was headed for a \"significant recession. But there was confusion about the \u201cback to work\u201d guidance, first announced by U.K. Prime Minister Boris Johnson on Sunday. Critics of Johnson's Conservative government say the changes, spelled out in a 50-page document, are confusing and potentially dangerous. Johnson denied that there had been mixed messaging and told lawmakers that \u201cthe common sense of the British people is shining through.\u201d One of the main concerns centers on how people can travel to work while keeping to social distancing requirements, especially in London, where most commuters use public transit. Transport for London said that in the morning hours up to 10 a.m., the number of passengers on the capital\u2019s subway system was around 7.3% higher than on the same day last week. Carl Moss, 39, traveling to his job as a gardener at St. Thomas\u2019 Hospital in central London, said it's been \u201cbusier today\u201d and that he'd seen \u201cmore office, finance-type people\u201d as well as manual workers. The union that represents train drivers voiced concerns about overcrowding following images on social media showing passengers crowded together on Tube trains and buses. At London's Victoria train and subway station, worker Linda Freitas said she felt \u201canxious and a bit scared\u201d about the prospect of more commuters. A ticket office worker at the station died with COVID-19 last month after being spat at by a man claiming to have the coronavirus. \u201cIf it\u2019s done gradually let\u2019s see, but if it\u2019s too many people then it will be a bit of a problem,\" Freitas said. Meanwhile, Johnson is under fire for his government's handling of an outbreak that has infected more than 200,000 Britons \u2014 including the prime minister, who spent three nights in intensive care last month. On Wednesday, the government announced 600 million pounds ($735 million) in funding to stop coronavirus infections in nursing homes. But opponents said the money was too late to save thousands of vulnerable residents. More than 8,000 people with the coronavirus died in nursing homes up to the start of May, according to Britain\u2019s Office for National Statistics, and the full figure is likely substantially higher. Keir Starmer, the leader of the opposition Labour Party, accused the government of being lax for releasing people from hospitals into nursing homes earlier in the outbreak without testing them for the coronavirus. Johnson called the situation in care homes \u201ca tragedy\u201d but said the number of infections and deaths was now falling."


def combine(data):
    
    res = []
    l = len(data['ents'])
    text = data['text']
    
    def combineHelper(path, idx, count):
        if count == 2:
            e1 = path[0]['text']
            e1_label = path[0]['type']
            e2 = path[1]['text']
            e2_label = path[1]['type']
            e11 = path[0]['start']
            e12 = path[0]['end']
            e21 = path[1]['start']
            e22 = path[1]['end']
            new_text = text[:e11] + '<e1>' + text[e11:e12] + '</e1> ' + text[e12:e21] + '<e2>' + text[e21:e22] +\
            '</e2>' + text[e22:]
            res.append(
                {
                    "text": new_text.strip(),
                    "e1": e1,
                    "e2": e2,
                    "e1_label": e1_label,
                    "e2_label": e2_label,
                    "e1_id": path[0]['id'],
                    "e2_id": path[1]['id']
                }
            )
            return
        else:
            for i in range(idx, l):
                path.append(data['ents'][i])
                combineHelper(path, i+1, count+1)
                path.pop()
        
    combineHelper([], 0, 0)
    return res

def generateTextToNer(text):
    clean_text = normalize_corpus([text], to_lower=False, to_remove_html=False,
                                  to_remove_accent=True, to_expand_contractions=True,
                                  to_lemmatize=False, to_remove_special=False,
                                  to_remove_stopword=False)
    clean_text = clean_text[0]
    sentence = Sentence(clean_text, use_tokenizer=True)
    tagger_fast.predict(sentence)

    idTracker = defaultdict(int)

    dict_flair = sentence.to_dict(tag_type='ner')
    for idx in dict_flair['entities']:
        idx['id'] = idTracker[idx['text']]
        idTracker[idx['text']] += 1
        idx['end'] = idx.pop('end_pos')
        idx['start'] = idx.pop('start_pos')
        full_label = idx.pop('labels')[0]
        full_label = str(full_label)
        idx['type'] = full_label[:full_label.find(' ')]
    dict_flair.pop('labels')
    dict_flair['ents'] = dict_flair.pop('entities')
    return dict_flair


def generateNerToRelation(text):
    clean_text = normalize_corpus([text], to_lower=False, to_remove_html=False,
                                  to_remove_accent=True, to_expand_contractions=True,
                                  to_lemmatize=False, to_remove_special=False,
                                  to_remove_stopword=False)
    clean_text = clean_text[0]
    lst_sentences = nltk.sent_tokenize(clean_text)

    res = []
    idTracker = defaultdict(int)

    for s in lst_sentences:
        sentence = Sentence(s, use_tokenizer=True)
        tagger_fast.predict(sentence)
        d = sentence.to_dict(tag_type='ner')
        d.pop('labels')
        for idx in d['entities']:
            idx['id'] = idTracker[idx['text']]
            idTracker[idx['text']] += 1
            idx['end'] = idx.pop('end_pos')
            idx['start'] = idx.pop('start_pos')
            full_label = idx.pop('labels')[0]
            full_label = str(full_label)
            idx['type'] = full_label[:full_label.find(' ')]
        d['ents'] = d.pop('entities')
        combination = combine(d)
        res.extend(combination)
    return res
# Out:
# 2020-06-03 11:43:49,212 loading file /Users/SamuelDNinja/.flair/models/en-ner-ontonotes-fast-v0.4.pt

# %%
generateNerToRelation(raw)
# Out:
# [{'text': '<e1>LONDON</e1>  The sound of crisply struck golf balls could be heard in <e2>England</e2> for the first time in nearly two months as courses reopened Wednesday, part of a modest easing of coronavirus lockdown restrictions.',
#   'e1': 'LONDON',
#   'e2': 'England',
#   'e1_label': 'GPE',
#   'e2_label': 'GPE',
#   'e1_id': 0,
#   'e2_id': 0},
#  {'text': '<e1>LONDON</e1>  The sound of crisply struck golf balls could be heard in England for the <e2>first</e2> time in nearly two months as courses reopened Wednesday, part of a modest easing of coronavirus lockdown restrictions.',
#   'e1': 'LONDON',
#   'e2': 'first',
#   'e1_label': 'GPE',
#   'e2_label': 'ORDINAL',
#   'e1_id': 0,
#   'e2_id': 0},
#  {'text': '<e1>LONDON</e1>  The sound of crisply struck golf balls could be heard in England for the first time in <e2>nearly two months</e2> as courses reopened Wednesday, part of a modest easing of coronavirus lockdown restrictions.',
#   'e1': 'LONDON',
#   'e2': 'nearly two months',
#   'e1_label': 'GPE',
#   'e2_label': 'DATE',
#   'e1_id': 0,
#   'e2_id': 0},
#  {'text': '<e1>LONDON</e1>  The sound of crisply struck golf balls could be heard in England for the first time in nearly two months as courses reopened <e2>Wednesday</e2>, part of a modest easing of coronavirus lockdown restrictions.',
#   'e1': 'LONDON',
#   'e2': 'Wednesday',
#   'e1_label': 'GPE',
#   'e2_label': 'DATE',
#   'e1_id': 0,
#   'e2_id': 0},
#  {'text': 'LONDON The sound of crisply struck golf balls could be heard in <e1>England</e1>  for the <e2>first</e2> time in nearly two months as courses reopened Wednesday, part of a modest easing of coronavirus lockdown restrictions.',
#   'e1': 'England',
#   'e2': 'first',
#   'e1_label': 'GPE',
#   'e2_label': 'ORDINAL',
#   'e1_id': 0,
#   'e2_id': 0},
#  {'text': 'LONDON The sound of crisply struck golf balls could be heard in <e1>England</e1>  for the first time in <e2>nearly two months</e2> as courses reopened Wednesday, part of a modest easing of coronavirus lockdown restrictions.',
#   'e1': 'England',
#   'e2': 'nearly two months',
#   'e1_label': 'GPE',
#   'e2_label': 'DATE',
#   'e1_id': 0,
#   'e2_id': 0},
#  {'text': 'LONDON The sound of crisply struck golf balls could be heard in <e1>England</e1>  for the first time in nearly two months as courses reopened <e2>Wednesday</e2>, part of a modest easing of coronavirus lockdown restrictions.',
#   'e1': 'England',
#   'e2': 'Wednesday',
#   'e1_label': 'GPE',
#   'e2_label': 'DATE',
#   'e1_id': 0,
#   'e2_id': 0},
#  {'text': 'LONDON The sound of crisply struck golf balls could be heard in England for the <e1>first</e1>  time in <e2>nearly two months</e2> as courses reopened Wednesday, part of a modest easing of coronavirus lockdown restrictions.',
#   'e1': 'first',
#   'e2': 'nearly two months',
#   'e1_label': 'ORDINAL',
#   'e2_label': 'DATE',
#   'e1_id': 0,
#   'e2_id': 0},
#  {'text': 'LONDON The sound of crisply struck golf balls could be heard in England for the <e1>first</e1>  time in nearly two months as courses reopened <e2>Wednesday</e2>, part of a modest easing of coronavirus lockdown restrictions.',
#   'e1': 'first',
#   'e2': 'Wednesday',
#   'e1_label': 'ORDINAL',
#   'e2_label': 'DATE',
#   'e1_id': 0,
#   'e2_id': 0},
#  {'text': 'LONDON The sound of crisply struck golf balls could be heard in England for the first time in <e1>nearly two months</e1>  as courses reopened <e2>Wednesday</e2>, part of a modest easing of coronavirus lockdown restrictions.',
#   'e1': 'nearly two months',
#   'e2': 'Wednesday',
#   'e1_label': 'DATE',
#   'e2_label': 'DATE',
#   'e1_id': 0,
#   'e2_id': 0},
#  {'text': 'After <e1>seven weeks</e1>  of lockdown, people in <e2>England</e2> were allowed to exercise more than once a day and with one person from outside their household, provided they remained 2 meters (around 6.5 feet) apart.',
#   'e1': 'seven weeks',
#   'e2': 'England',
#   'e1_label': 'DATE',
#   'e2_label': 'GPE',
#   'e1_id': 0,
#   'e2_id': 1},
#  {'text': 'After <e1>seven weeks</e1>  of lockdown, people in England were allowed to exercise more than once a day and with <e2>one</e2> person from outside their household, provided they remained 2 meters (around 6.5 feet) apart.',
#   'e1': 'seven weeks',
#   'e2': 'one',
#   'e1_label': 'DATE',
#   'e2_label': 'CARDINAL',
#   'e1_id': 0,
#   'e2_id': 0},
#  {'text': 'After <e1>seven weeks</e1>  of lockdown, people in England were allowed to exercise more than once a day and with one person from outside their household, provided they remained <e2>2 meters</e2> (around 6.5 feet) apart.',
#   'e1': 'seven weeks',
#   'e2': '2 meters',
#   'e1_label': 'DATE',
#   'e2_label': 'QUANTITY',
#   'e1_id': 0,
#   'e2_id': 0},
#  {'text': 'After <e1>seven weeks</e1>  of lockdown, people in England were allowed to exercise more than once a day and with one person from outside their household, provided they remained 2 meters (<e2>around 6.5 feet</e2>) apart.',
#   'e1': 'seven weeks',
#   'e2': 'around 6.5 feet',
#   'e1_label': 'DATE',
#   'e2_label': 'QUANTITY',
#   'e1_id': 0,
#   'e2_id': 0},
#  {'text': 'After seven weeks of lockdown, people in <e1>England</e1>  were allowed to exercise more than once a day and with <e2>one</e2> person from outside their household, provided they remained 2 meters (around 6.5 feet) apart.',
#   'e1': 'England',
#   'e2': 'one',
#   'e1_label': 'GPE',
#   'e2_label': 'CARDINAL',
#   'e1_id': 1,
#   'e2_id': 0},
#  {'text': 'After seven weeks of lockdown, people in <e1>England</e1>  were allowed to exercise more than once a day and with one person from outside their household, provided they remained <e2>2 meters</e2> (around 6.5 feet) apart.',
#   'e1': 'England',
#   'e2': '2 meters',
#   'e1_label': 'GPE',
#   'e2_label': 'QUANTITY',
#   'e1_id': 1,
#   'e2_id': 0},
#  {'text': 'After seven weeks of lockdown, people in <e1>England</e1>  were allowed to exercise more than once a day and with one person from outside their household, provided they remained 2 meters (<e2>around 6.5 feet</e2>) apart.',
#   'e1': 'England',
#   'e2': 'around 6.5 feet',
#   'e1_label': 'GPE',
#   'e2_label': 'QUANTITY',
#   'e1_id': 1,
#   'e2_id': 0},
#  {'text': 'After seven weeks of lockdown, people in England were allowed to exercise more than once a day and with <e1>one</e1>  person from outside their household, provided they remained <e2>2 meters</e2> (around 6.5 feet) apart.',
#   'e1': 'one',
#   'e2': '2 meters',
#   'e1_label': 'CARDINAL',
#   'e2_label': 'QUANTITY',
#   'e1_id': 0,
#   'e2_id': 0},
#  {'text': 'After seven weeks of lockdown, people in England were allowed to exercise more than once a day and with <e1>one</e1>  person from outside their household, provided they remained 2 meters (<e2>around 6.5 feet</e2>) apart.',
#   'e1': 'one',
#   'e2': 'around 6.5 feet',
#   'e1_label': 'CARDINAL',
#   'e2_label': 'QUANTITY',
#   'e1_id': 0,
#   'e2_id': 0},
#  {'text': 'After seven weeks of lockdown, people in England were allowed to exercise more than once a day and with one person from outside their household, provided they remained <e1>2 meters</e1>  (<e2>around 6.5 feet</e2>) apart.',
#   'e1': '2 meters',
#   'e2': 'around 6.5 feet',
#   'e1_label': 'QUANTITY',
#   'e2_label': 'QUANTITY',
#   'e1_id': 0,
#   'e2_id': 0},
#  {'text': '<e1>David Baillie</e1> , the pro at <e2>Dulwich & Sydenham Hill Golf Club</e2> in southeast London, said 170 members booked tee-off times to play in pairs on Wednesday and that all slots are taken through Tuesday.',
#   'e1': 'David Baillie',
#   'e2': 'Dulwich & Sydenham Hill Golf Club',
#   'e1_label': 'PERSON',
#   'e2_label': 'ORG',
#   'e1_id': 0,
#   'e2_id': 0},
#  {'text': '<e1>David Baillie</e1> , the pro at Dulwich & Sydenham Hill Golf Club in southeast <e2>London</e2>, said 170 members booked tee-off times to play in pairs on Wednesday and that all slots are taken through Tuesday.',
#   'e1': 'David Baillie',
#   'e2': 'London',
#   'e1_label': 'PERSON',
#   'e2_label': 'GPE',
#   'e1_id': 0,
#   'e2_id': 0},
#  {'text': '<e1>David Baillie</e1> , the pro at Dulwich & Sydenham Hill Golf Club in southeast London, said <e2>170</e2> members booked tee-off times to play in pairs on Wednesday and that all slots are taken through Tuesday.',
#   'e1': 'David Baillie',
#   'e2': '170',
#   'e1_label': 'PERSON',
#   'e2_label': 'CARDINAL',
#   'e1_id': 0,
#   'e2_id': 0},
#  {'text': '<e1>David Baillie</e1> , the pro at Dulwich & Sydenham Hill Golf Club in southeast London, said 170 members booked tee-off times to play in pairs on <e2>Wednesday</e2> and that all slots are taken through Tuesday.',
#   'e1': 'David Baillie',
#   'e2': 'Wednesday',
#   'e1_label': 'PERSON',
#   'e2_label': 'DATE',
#   'e1_id': 0,
#   'e2_id': 1},
#  {'text': '<e1>David Baillie</e1> , the pro at Dulwich & Sydenham Hill Golf Club in southeast London, said 170 members booked tee-off times to play in pairs on Wednesday and that all slots are taken through <e2>Tuesday</e2>.',
#   'e1': 'David Baillie',
#   'e2': 'Tuesday',
#   'e1_label': 'PERSON',
#   'e2_label': 'DATE',
#   'e1_id': 0,
#   'e2_id': 0},
#  {'text': 'David Baillie, the pro at <e1>Dulwich & Sydenham Hill Golf Club</e1>  in southeast <e2>London</e2>, said 170 members booked tee-off times to play in pairs on Wednesday and that all slots are taken through Tuesday.',
#   'e1': 'Dulwich & Sydenham Hill Golf Club',
#   'e2': 'London',
#   'e1_label': 'ORG',
#   'e2_label': 'GPE',
#   'e1_id': 0,
#   'e2_id': 0},
#  {'text': 'David Baillie, the pro at <e1>Dulwich & Sydenham Hill Golf Club</e1>  in southeast London, said <e2>170</e2> members booked tee-off times to play in pairs on Wednesday and that all slots are taken through Tuesday.',
#   'e1': 'Dulwich & Sydenham Hill Golf Club',
#   'e2': '170',
#   'e1_label': 'ORG',
#   'e2_label': 'CARDINAL',
#   'e1_id': 0,
#   'e2_id': 0},
#  {'text': 'David Baillie, the pro at <e1>Dulwich & Sydenham Hill Golf Club</e1>  in southeast London, said 170 members booked tee-off times to play in pairs on <e2>Wednesday</e2> and that all slots are taken through Tuesday.',
#   'e1': 'Dulwich & Sydenham Hill Golf Club',
#   'e2': 'Wednesday',
#   'e1_label': 'ORG',
#   'e2_label': 'DATE',
#   'e1_id': 0,
#   'e2_id': 1},
#  {'text': 'David Baillie, the pro at <e1>Dulwich & Sydenham Hill Golf Club</e1>  in southeast London, said 170 members booked tee-off times to play in pairs on Wednesday and that all slots are taken through <e2>Tuesday</e2>.',
#   'e1': 'Dulwich & Sydenham Hill Golf Club',
#   'e2': 'Tuesday',
#   'e1_label': 'ORG',
#   'e2_label': 'DATE',
#   'e1_id': 0,
#   'e2_id': 0},
#  {'text': 'David Baillie, the pro at Dulwich & Sydenham Hill Golf Club in southeast <e1>London</e1> , said <e2>170</e2> members booked tee-off times to play in pairs on Wednesday and that all slots are taken through Tuesday.',
#   'e1': 'London',
#   'e2': '170',
#   'e1_label': 'GPE',
#   'e2_label': 'CARDINAL',
#   'e1_id': 0,
#   'e2_id': 0},
#  {'text': 'David Baillie, the pro at Dulwich & Sydenham Hill Golf Club in southeast <e1>London</e1> , said 170 members booked tee-off times to play in pairs on <e2>Wednesday</e2> and that all slots are taken through Tuesday.',
#   'e1': 'London',
#   'e2': 'Wednesday',
#   'e1_label': 'GPE',
#   'e2_label': 'DATE',
#   'e1_id': 0,
#   'e2_id': 1},
#  {'text': 'David Baillie, the pro at Dulwich & Sydenham Hill Golf Club in southeast <e1>London</e1> , said 170 members booked tee-off times to play in pairs on Wednesday and that all slots are taken through <e2>Tuesday</e2>.',
#   'e1': 'London',
#   'e2': 'Tuesday',
#   'e1_label': 'GPE',
#   'e2_label': 'DATE',
#   'e1_id': 0,
#   'e2_id': 0},
#  {'text': 'David Baillie, the pro at Dulwich & Sydenham Hill Golf Club in southeast London, said <e1>170</e1>  members booked tee-off times to play in pairs on <e2>Wednesday</e2> and that all slots are taken through Tuesday.',
#   'e1': '170',
#   'e2': 'Wednesday',
#   'e1_label': 'CARDINAL',
#   'e2_label': 'DATE',
#   'e1_id': 0,
#   'e2_id': 1},
#  {'text': 'David Baillie, the pro at Dulwich & Sydenham Hill Golf Club in southeast London, said <e1>170</e1>  members booked tee-off times to play in pairs on Wednesday and that all slots are taken through <e2>Tuesday</e2>.',
#   'e1': '170',
#   'e2': 'Tuesday',
#   'e1_label': 'CARDINAL',
#   'e2_label': 'DATE',
#   'e1_id': 0,
#   'e2_id': 0},
#  {'text': 'David Baillie, the pro at Dulwich & Sydenham Hill Golf Club in southeast London, said 170 members booked tee-off times to play in pairs on <e1>Wednesday</e1>  and that all slots are taken through <e2>Tuesday</e2>.',
#   'e1': 'Wednesday',
#   'e2': 'Tuesday',
#   'e1_label': 'DATE',
#   'e2_label': 'DATE',
#   'e1_id': 1,
#   'e2_id': 0},
#  {'text': 'Some construction sites have resumed work, and automaker <e1>Ford</e1>  announced plans to restart production at <e2>two</e2> factories in the U.K.',
#   'e1': 'Ford',
#   'e2': 'two',
#   'e1_label': 'ORG',
#   'e2_label': 'CARDINAL',
#   'e1_id': 0,
#   'e2_id': 0},
#  {'text': 'Some construction sites have resumed work, and automaker <e1>Ford</e1>  announced plans to restart production at two factories in the <e2>U.K</e2>.',
#   'e1': 'Ford',
#   'e2': 'U.K',
#   'e1_label': 'ORG',
#   'e2_label': 'GPE',
#   'e1_id': 0,
#   'e2_id': 0},
#  {'text': 'Some construction sites have resumed work, and automaker Ford announced plans to restart production at <e1>two</e1>  factories in the <e2>U.K</e2>.',
#   'e1': 'two',
#   'e2': 'U.K',
#   'e1_label': 'CARDINAL',
#   'e2_label': 'GPE',
#   'e1_id': 0,
#   'e2_id': 0},
#  {'text': 'The semi-autonomous governments of <e1>Scotland</e1> , <e2>Wales</e2> and Northern Ireland are going more slowly and sticking with the Stay Home message, partly because the epidemic is at different stages in different parts of the country, Johnson justified the modest easing on the grounds that Britain has passed the peak of the outbreak, with deaths and new infections in decline.',
#   'e1': 'Scotland',
#   'e2': 'Wales',
#   'e1_label': 'GPE',
#   'e2_label': 'GPE',
#   'e1_id': 0,
#   'e2_id': 0},
#  {'text': 'The semi-autonomous governments of <e1>Scotland</e1> , Wales and <e2>Northern Ireland</e2> are going more slowly and sticking with the Stay Home message, partly because the epidemic is at different stages in different parts of the country, Johnson justified the modest easing on the grounds that Britain has passed the peak of the outbreak, with deaths and new infections in decline.',
#   'e1': 'Scotland',
#   'e2': 'Northern Ireland',
#   'e1_label': 'GPE',
#   'e2_label': 'GPE',
#   'e1_id': 0,
#   'e2_id': 0},
#  {'text': 'The semi-autonomous governments of <e1>Scotland</e1> , Wales and Northern Ireland are going more slowly and sticking with the Stay Home message, partly because the epidemic is at different stages in different parts of the country, <e2>Johnson</e2> justified the modest easing on the grounds that Britain has passed the peak of the outbreak, with deaths and new infections in decline.',
#   'e1': 'Scotland',
#   'e2': 'Johnson',
#   'e1_label': 'GPE',
#   'e2_label': 'PERSON',
#   'e1_id': 0,
#   'e2_id': 0},
#  {'text': 'The semi-autonomous governments of <e1>Scotland</e1> , Wales and Northern Ireland are going more slowly and sticking with the Stay Home message, partly because the epidemic is at different stages in different parts of the country, Johnson justified the modest easing on the grounds that <e2>Britain</e2> has passed the peak of the outbreak, with deaths and new infections in decline.',
#   'e1': 'Scotland',
#   'e2': 'Britain',
#   'e1_label': 'GPE',
#   'e2_label': 'GPE',
#   'e1_id': 0,
#   'e2_id': 0},
#  {'text': 'The semi-autonomous governments of Scotland, <e1>Wales</e1>  and <e2>Northern Ireland</e2> are going more slowly and sticking with the Stay Home message, partly because the epidemic is at different stages in different parts of the country, Johnson justified the modest easing on the grounds that Britain has passed the peak of the outbreak, with deaths and new infections in decline.',
#   'e1': 'Wales',
#   'e2': 'Northern Ireland',
#   'e1_label': 'GPE',
#   'e2_label': 'GPE',
#   'e1_id': 0,
#   'e2_id': 0},
#  {'text': 'The semi-autonomous governments of Scotland, <e1>Wales</e1>  and Northern Ireland are going more slowly and sticking with the Stay Home message, partly because the epidemic is at different stages in different parts of the country, <e2>Johnson</e2> justified the modest easing on the grounds that Britain has passed the peak of the outbreak, with deaths and new infections in decline.',
#   'e1': 'Wales',
#   'e2': 'Johnson',
#   'e1_label': 'GPE',
#   'e2_label': 'PERSON',
#   'e1_id': 0,
#   'e2_id': 0},
#  {'text': 'The semi-autonomous governments of Scotland, <e1>Wales</e1>  and Northern Ireland are going more slowly and sticking with the Stay Home message, partly because the epidemic is at different stages in different parts of the country, Johnson justified the modest easing on the grounds that <e2>Britain</e2> has passed the peak of the outbreak, with deaths and new infections in decline.',
#   'e1': 'Wales',
#   'e2': 'Britain',
#   'e1_label': 'GPE',
#   'e2_label': 'GPE',
#   'e1_id': 0,
#   'e2_id': 0},
#  {'text': 'The semi-autonomous governments of Scotland, Wales and <e1>Northern Ireland</e1>  are going more slowly and sticking with the Stay Home message, partly because the epidemic is at different stages in different parts of the country, <e2>Johnson</e2> justified the modest easing on the grounds that Britain has passed the peak of the outbreak, with deaths and new infections in decline.',
#   'e1': 'Northern Ireland',
#   'e2': 'Johnson',
#   'e1_label': 'GPE',
#   'e2_label': 'PERSON',
#   'e1_id': 0,
#   'e2_id': 0},
#  {'text': 'The semi-autonomous governments of Scotland, Wales and <e1>Northern Ireland</e1>  are going more slowly and sticking with the Stay Home message, partly because the epidemic is at different stages in different parts of the country, Johnson justified the modest easing on the grounds that <e2>Britain</e2> has passed the peak of the outbreak, with deaths and new infections in decline.',
#   'e1': 'Northern Ireland',
#   'e2': 'Britain',
#   'e1_label': 'GPE',
#   'e2_label': 'GPE',
#   'e1_id': 0,
#   'e2_id': 0},
#  {'text': 'The semi-autonomous governments of Scotland, Wales and Northern Ireland are going more slowly and sticking with the Stay Home message, partly because the epidemic is at different stages in different parts of the country, <e1>Johnson</e1>  justified the modest easing on the grounds that <e2>Britain</e2> has passed the peak of the outbreak, with deaths and new infections in decline.',
#   'e1': 'Johnson',
#   'e2': 'Britain',
#   'e1_label': 'PERSON',
#   'e2_label': 'GPE',
#   'e1_id': 0,
#   'e2_id': 0},
#  {'text': 'The <e1>U.K.</e1>  has officially recorded the most coronavirus-related deaths in <e2>Europe</e2>, more than 33,000, a toll second only to the United States.',
#   'e1': 'U.K.',
#   'e2': 'Europe',
#   'e1_label': 'GPE',
#   'e2_label': 'LOC',
#   'e1_id': 0,
#   'e2_id': 0},
#  {'text': 'The <e1>U.K.</e1>  has officially recorded the most coronavirus-related deaths in Europe, <e2>more than 33,000</e2>, a toll second only to the United States.',
#   'e1': 'U.K.',
#   'e2': 'more than 33,000',
#   'e1_label': 'GPE',
#   'e2_label': 'CARDINAL',
#   'e1_id': 0,
#   'e2_id': 0},
#  {'text': 'The <e1>U.K.</e1>  has officially recorded the most coronavirus-related deaths in Europe, more than 33,000, a toll <e2>second</e2> only to the United States.',
#   'e1': 'U.K.',
#   'e2': 'second',
#   'e1_label': 'GPE',
#   'e2_label': 'ORDINAL',
#   'e1_id': 0,
#   'e2_id': 0},
#  {'text': 'The <e1>U.K.</e1>  has officially recorded the most coronavirus-related deaths in Europe, more than 33,000, a toll second only to <e2>the United States</e2>.',
#   'e1': 'U.K.',
#   'e2': 'the United States',
#   'e1_label': 'GPE',
#   'e2_label': 'GPE',
#   'e1_id': 0,
#   'e2_id': 0},
#  {'text': 'The U.K. has officially recorded the most coronavirus-related deaths in <e1>Europe</e1> , <e2>more than 33,000</e2>, a toll second only to the United States.',
#   'e1': 'Europe',
#   'e2': 'more than 33,000',
#   'e1_label': 'LOC',
#   'e2_label': 'CARDINAL',
#   'e1_id': 0,
#   'e2_id': 0},
#  {'text': 'The U.K. has officially recorded the most coronavirus-related deaths in <e1>Europe</e1> , more than 33,000, a toll <e2>second</e2> only to the United States.',
#   'e1': 'Europe',
#   'e2': 'second',
#   'e1_label': 'LOC',
#   'e2_label': 'ORDINAL',
#   'e1_id': 0,
#   'e2_id': 0},
#  {'text': 'The U.K. has officially recorded the most coronavirus-related deaths in <e1>Europe</e1> , more than 33,000, a toll second only to <e2>the United States</e2>.',
#   'e1': 'Europe',
#   'e2': 'the United States',
#   'e1_label': 'LOC',
#   'e2_label': 'GPE',
#   'e1_id': 0,
#   'e2_id': 0},
#  {'text': 'The U.K. has officially recorded the most coronavirus-related deaths in Europe, <e1>more than 33,000</e1> , a toll <e2>second</e2> only to the United States.',
#   'e1': 'more than 33,000',
#   'e2': 'second',
#   'e1_label': 'CARDINAL',
#   'e2_label': 'ORDINAL',
#   'e1_id': 0,
#   'e2_id': 0},
#  {'text': 'The U.K. has officially recorded the most coronavirus-related deaths in Europe, <e1>more than 33,000</e1> , a toll second only to <e2>the United States</e2>.',
#   'e1': 'more than 33,000',
#   'e2': 'the United States',
#   'e1_label': 'CARDINAL',
#   'e2_label': 'GPE',
#   'e1_id': 0,
#   'e2_id': 0},
#  {'text': 'The U.K. has officially recorded the most coronavirus-related deaths in Europe, more than 33,000, a toll <e1>second</e1>  only to <e2>the United States</e2>.',
#   'e1': 'second',
#   'e2': 'the United States',
#   'e1_label': 'ORDINAL',
#   'e2_label': 'GPE',
#   'e1_id': 0,
#   'e2_id': 0},
#  {'text': 'The government is trying to defeat the outbreak while gradually restarting an economy that shrank by <e1>2%</e1>  in <e2>the first quarter of the year</e2>, with output falling 5.8% in March, the month everyday life began to shut down.',
#   'e1': '2%',
#   'e2': 'the first quarter of the year',
#   'e1_label': 'PERCENT',
#   'e2_label': 'DATE',
#   'e1_id': 0,
#   'e2_id': 0},
#  {'text': 'The government is trying to defeat the outbreak while gradually restarting an economy that shrank by <e1>2%</e1>  in the first quarter of the year, with output falling <e2>5.8%</e2> in March, the month everyday life began to shut down.',
#   'e1': '2%',
#   'e2': '5.8%',
#   'e1_label': 'PERCENT',
#   'e2_label': 'PERCENT',
#   'e1_id': 0,
#   'e2_id': 0},
#  {'text': 'The government is trying to defeat the outbreak while gradually restarting an economy that shrank by <e1>2%</e1>  in the first quarter of the year, with output falling 5.8% in <e2>March</e2>, the month everyday life began to shut down.',
#   'e1': '2%',
#   'e2': 'March',
#   'e1_label': 'PERCENT',
#   'e2_label': 'DATE',
#   'e1_id': 0,
#   'e2_id': 0},
#  {'text': 'The government is trying to defeat the outbreak while gradually restarting an economy that shrank by <e1>2%</e1>  in the first quarter of the year, with output falling 5.8% in March, <e2>the month</e2> everyday life began to shut down.',
#   'e1': '2%',
#   'e2': 'the month',
#   'e1_label': 'PERCENT',
#   'e2_label': 'DATE',
#   'e1_id': 0,
#   'e2_id': 0},
#  {'text': 'The government is trying to defeat the outbreak while gradually restarting an economy that shrank by 2% in <e1>the first quarter of the year</e1> , with output falling <e2>5.8%</e2> in March, the month everyday life began to shut down.',
#   'e1': 'the first quarter of the year',
#   'e2': '5.8%',
#   'e1_label': 'DATE',
#   'e2_label': 'PERCENT',
#   'e1_id': 0,
#   'e2_id': 0},
#  {'text': 'The government is trying to defeat the outbreak while gradually restarting an economy that shrank by 2% in <e1>the first quarter of the year</e1> , with output falling 5.8% in <e2>March</e2>, the month everyday life began to shut down.',
#   'e1': 'the first quarter of the year',
#   'e2': 'March',
#   'e1_label': 'DATE',
#   'e2_label': 'DATE',
#   'e1_id': 0,
#   'e2_id': 0},
#  {'text': 'The government is trying to defeat the outbreak while gradually restarting an economy that shrank by 2% in <e1>the first quarter of the year</e1> , with output falling 5.8% in March, <e2>the month</e2> everyday life began to shut down.',
#   'e1': 'the first quarter of the year',
#   'e2': 'the month',
#   'e1_label': 'DATE',
#   'e2_label': 'DATE',
#   'e1_id': 0,
#   'e2_id': 0},
#  {'text': 'The government is trying to defeat the outbreak while gradually restarting an economy that shrank by 2% in the first quarter of the year, with output falling <e1>5.8%</e1>  in <e2>March</e2>, the month everyday life began to shut down.',
#   'e1': '5.8%',
#   'e2': 'March',
#   'e1_label': 'PERCENT',
#   'e2_label': 'DATE',
#   'e1_id': 0,
#   'e2_id': 0},
#  {'text': 'The government is trying to defeat the outbreak while gradually restarting an economy that shrank by 2% in the first quarter of the year, with output falling <e1>5.8%</e1>  in March, <e2>the month</e2> everyday life began to shut down.',
#   'e1': '5.8%',
#   'e2': 'the month',
#   'e1_label': 'PERCENT',
#   'e2_label': 'DATE',
#   'e1_id': 0,
#   'e2_id': 0},
#  {'text': 'The government is trying to defeat the outbreak while gradually restarting an economy that shrank by 2% in the first quarter of the year, with output falling 5.8% in <e1>March</e1> , <e2>the month</e2> everyday life began to shut down.',
#   'e1': 'March',
#   'e2': 'the month',
#   'e1_label': 'DATE',
#   'e2_label': 'DATE',
#   'e1_id': 0,
#   'e2_id': 0},
#  {'text': '<e1>Treasury</e1>  chief <e2>Rishi Sunak</e2> said the U.K. was headed for a "significant recession.',
#   'e1': 'Treasury',
#   'e2': 'Rishi Sunak',
#   'e1_label': 'ORG',
#   'e2_label': 'PERSON',
#   'e1_id': 0,
#   'e2_id': 0},
#  {'text': '<e1>Treasury</e1>  chief Rishi Sunak said the <e2>U.K.</e2> was headed for a "significant recession.',
#   'e1': 'Treasury',
#   'e2': 'U.K.',
#   'e1_label': 'ORG',
#   'e2_label': 'GPE',
#   'e1_id': 0,
#   'e2_id': 1},
#  {'text': 'Treasury chief <e1>Rishi Sunak</e1>  said the <e2>U.K.</e2> was headed for a "significant recession.',
#   'e1': 'Rishi Sunak',
#   'e2': 'U.K.',
#   'e1_label': 'PERSON',
#   'e2_label': 'GPE',
#   'e1_id': 0,
#   'e2_id': 1},
#  {'text': 'But there was confusion about the back to work guidance, first announced by <e1>U.K.</e1>  Prime Minister <e2>Boris Johnson</e2> on Sunday.',
#   'e1': 'U.K.',
#   'e2': 'Boris Johnson',
#   'e1_label': 'GPE',
#   'e2_label': 'PERSON',
#   'e1_id': 2,
#   'e2_id': 0},
#  {'text': 'But there was confusion about the back to work guidance, first announced by <e1>U.K.</e1>  Prime Minister Boris Johnson on <e2>Sunday</e2>.',
#   'e1': 'U.K.',
#   'e2': 'Sunday',
#   'e1_label': 'GPE',
#   'e2_label': 'DATE',
#   'e1_id': 2,
#   'e2_id': 0},
#  {'text': 'But there was confusion about the back to work guidance, first announced by U.K. Prime Minister <e1>Boris Johnson</e1>  on <e2>Sunday</e2>.',
#   'e1': 'Boris Johnson',
#   'e2': 'Sunday',
#   'e1_label': 'PERSON',
#   'e2_label': 'DATE',
#   'e1_id': 0,
#   'e2_id': 0},
#  {'text': '<e1>Johnson</e1>  denied that there had been mixed messaging and told lawmakers that the common sense of the <e2>British</e2> people is shining through.',
#   'e1': 'Johnson',
#   'e2': 'British',
#   'e1_label': 'PERSON',
#   'e2_label': 'NORP',
#   'e1_id': 1,
#   'e2_id': 1},
#  {'text': '<e1>One</e1>  of the main concerns centers on how people can travel to work while keeping to social distancing requirements, especially in <e2>London</e2>, where most commuters use public transit.',
#   'e1': 'One',
#   'e2': 'London',
#   'e1_label': 'CARDINAL',
#   'e2_label': 'GPE',
#   'e1_id': 0,
#   'e2_id': 1},
#  {'text': '<e1>Transport for London</e1>  said that in <e2>the morning hours</e2> up to 10 a.m., the number of passengers on the capitals subway system was around 7.3% higher than on the same day last week.',
#   'e1': 'Transport for London',
#   'e2': 'the morning hours',
#   'e1_label': 'ORG',
#   'e2_label': 'TIME',
#   'e1_id': 0,
#   'e2_id': 0},
#  {'text': '<e1>Transport for London</e1>  said that in the morning hours <e2>up to 10 a.m.</e2>, the number of passengers on the capitals subway system was around 7.3% higher than on the same day last week.',
#   'e1': 'Transport for London',
#   'e2': 'up to 10 a.m.',
#   'e1_label': 'ORG',
#   'e2_label': 'TIME',
#   'e1_id': 0,
#   'e2_id': 0},
#  {'text': '<e1>Transport for London</e1>  said that in the morning hours up to 10 a.m., the number of passengers on the capitals subway system was <e2>around 7.3%</e2> higher than on the same day last week.',
#   'e1': 'Transport for London',
#   'e2': 'around 7.3%',
#   'e1_label': 'ORG',
#   'e2_label': 'PERCENT',
#   'e1_id': 0,
#   'e2_id': 0},
#  {'text': '<e1>Transport for London</e1>  said that in the morning hours up to 10 a.m., the number of passengers on the capitals subway system was around 7.3% higher than on <e2>the same day last week</e2>.',
#   'e1': 'Transport for London',
#   'e2': 'the same day last week',
#   'e1_label': 'ORG',
#   'e2_label': 'DATE',
#   'e1_id': 0,
#   'e2_id': 0},
#  {'text': 'Transport for London said that in <e1>the morning hours</e1>  <e2>up to 10 a.m.</e2>, the number of passengers on the capitals subway system was around 7.3% higher than on the same day last week.',
#   'e1': 'the morning hours',
#   'e2': 'up to 10 a.m.',
#   'e1_label': 'TIME',
#   'e2_label': 'TIME',
#   'e1_id': 0,
#   'e2_id': 0},
#  {'text': 'Transport for London said that in <e1>the morning hours</e1>  up to 10 a.m., the number of passengers on the capitals subway system was <e2>around 7.3%</e2> higher than on the same day last week.',
#   'e1': 'the morning hours',
#   'e2': 'around 7.3%',
#   'e1_label': 'TIME',
#   'e2_label': 'PERCENT',
#   'e1_id': 0,
#   'e2_id': 0},
#  {'text': 'Transport for London said that in <e1>the morning hours</e1>  up to 10 a.m., the number of passengers on the capitals subway system was around 7.3% higher than on <e2>the same day last week</e2>.',
#   'e1': 'the morning hours',
#   'e2': 'the same day last week',
#   'e1_label': 'TIME',
#   'e2_label': 'DATE',
#   'e1_id': 0,
#   'e2_id': 0},
#  {'text': 'Transport for London said that in the morning hours <e1>up to 10 a.m.</e1> , the number of passengers on the capitals subway system was <e2>around 7.3%</e2> higher than on the same day last week.',
#   'e1': 'up to 10 a.m.',
#   'e2': 'around 7.3%',
#   'e1_label': 'TIME',
#   'e2_label': 'PERCENT',
#   'e1_id': 0,
#   'e2_id': 0},
#  {'text': 'Transport for London said that in the morning hours <e1>up to 10 a.m.</e1> , the number of passengers on the capitals subway system was around 7.3% higher than on <e2>the same day last week</e2>.',
#   'e1': 'up to 10 a.m.',
#   'e2': 'the same day last week',
#   'e1_label': 'TIME',
#   'e2_label': 'DATE',
#   'e1_id': 0,
#   'e2_id': 0},
#  {'text': 'Transport for London said that in the morning hours up to 10 a.m., the number of passengers on the capitals subway system was <e1>around 7.3%</e1>  higher than on <e2>the same day last week</e2>.',
#   'e1': 'around 7.3%',
#   'e2': 'the same day last week',
#   'e1_label': 'PERCENT',
#   'e2_label': 'DATE',
#   'e1_id': 0,
#   'e2_id': 0},
#  {'text': '<e1>Carl Moss</e1> , <e2>39</e2>, traveling to his job as a gardener at St. Thomas Hospital in central London, said it is been busier today and that he would seen more office, finance-type people as well as manual workers.',
#   'e1': 'Carl Moss',
#   'e2': '39',
#   'e1_label': 'PERSON',
#   'e2_label': 'DATE',
#   'e1_id': 0,
#   'e2_id': 0},
#  {'text': '<e1>Carl Moss</e1> , 39, traveling to his job as a gardener at <e2>St. Thomas Hospital</e2> in central London, said it is been busier today and that he would seen more office, finance-type people as well as manual workers.',
#   'e1': 'Carl Moss',
#   'e2': 'St. Thomas Hospital',
#   'e1_label': 'PERSON',
#   'e2_label': 'ORG',
#   'e1_id': 0,
#   'e2_id': 0},
#  {'text': '<e1>Carl Moss</e1> , 39, traveling to his job as a gardener at St. Thomas Hospital in central <e2>London</e2>, said it is been busier today and that he would seen more office, finance-type people as well as manual workers.',
#   'e1': 'Carl Moss',
#   'e2': 'London',
#   'e1_label': 'PERSON',
#   'e2_label': 'GPE',
#   'e1_id': 0,
#   'e2_id': 2},
#  {'text': '<e1>Carl Moss</e1> , 39, traveling to his job as a gardener at St. Thomas Hospital in central London, said it is been busier <e2>today</e2> and that he would seen more office, finance-type people as well as manual workers.',
#   'e1': 'Carl Moss',
#   'e2': 'today',
#   'e1_label': 'PERSON',
#   'e2_label': 'DATE',
#   'e1_id': 0,
#   'e2_id': 0},
#  {'text': 'Carl Moss, <e1>39</e1> , traveling to his job as a gardener at <e2>St. Thomas Hospital</e2> in central London, said it is been busier today and that he would seen more office, finance-type people as well as manual workers.',
#   'e1': '39',
#   'e2': 'St. Thomas Hospital',
#   'e1_label': 'DATE',
#   'e2_label': 'ORG',
#   'e1_id': 0,
#   'e2_id': 0},
#  {'text': 'Carl Moss, <e1>39</e1> , traveling to his job as a gardener at St. Thomas Hospital in central <e2>London</e2>, said it is been busier today and that he would seen more office, finance-type people as well as manual workers.',
#   'e1': '39',
#   'e2': 'London',
#   'e1_label': 'DATE',
#   'e2_label': 'GPE',
#   'e1_id': 0,
#   'e2_id': 2},
#  {'text': 'Carl Moss, <e1>39</e1> , traveling to his job as a gardener at St. Thomas Hospital in central London, said it is been busier <e2>today</e2> and that he would seen more office, finance-type people as well as manual workers.',
#   'e1': '39',
#   'e2': 'today',
#   'e1_label': 'DATE',
#   'e2_label': 'DATE',
#   'e1_id': 0,
#   'e2_id': 0},
#  {'text': 'Carl Moss, 39, traveling to his job as a gardener at <e1>St. Thomas Hospital</e1>  in central <e2>London</e2>, said it is been busier today and that he would seen more office, finance-type people as well as manual workers.',
#   'e1': 'St. Thomas Hospital',
#   'e2': 'London',
#   'e1_label': 'ORG',
#   'e2_label': 'GPE',
#   'e1_id': 0,
#   'e2_id': 2},
#  {'text': 'Carl Moss, 39, traveling to his job as a gardener at <e1>St. Thomas Hospital</e1>  in central London, said it is been busier <e2>today</e2> and that he would seen more office, finance-type people as well as manual workers.',
#   'e1': 'St. Thomas Hospital',
#   'e2': 'today',
#   'e1_label': 'ORG',
#   'e2_label': 'DATE',
#   'e1_id': 0,
#   'e2_id': 0},
#  {'text': 'Carl Moss, 39, traveling to his job as a gardener at St. Thomas Hospital in central <e1>London</e1> , said it is been busier <e2>today</e2> and that he would seen more office, finance-type people as well as manual workers.',
#   'e1': 'London',
#   'e2': 'today',
#   'e1_label': 'GPE',
#   'e2_label': 'DATE',
#   'e1_id': 2,
#   'e2_id': 0},
#  {'text': 'At <e1>Londons Victoria</e1>  train and subway station, worker <e2>Linda Freitas</e2> said she felt anxious and a bit scared about the prospect of more commuters.',
#   'e1': 'Londons Victoria',
#   'e2': 'Linda Freitas',
#   'e1_label': 'ORG',
#   'e2_label': 'PERSON',
#   'e1_id': 0,
#   'e2_id': 0},
#  {'text': 'A ticket office worker at the station died with <e1>COVID-19</e1>  <e2>last month</e2> after being spat at by a man claiming to have the coronavirus.',
#   'e1': 'COVID-19',
#   'e2': 'last month',
#   'e1_label': 'ORG',
#   'e2_label': 'DATE',
#   'e1_id': 0,
#   'e2_id': 0},
#  {'text': 'Meanwhile, <e1>Johnson</e1>  is under fire for his governments handling of an outbreak that has infected <e2>more than 200,000</e2> Britons including the prime minister, who spent three nights in intensive care last month.',
#   'e1': 'Johnson',
#   'e2': 'more than 200,000',
#   'e1_label': 'PERSON',
#   'e2_label': 'CARDINAL',
#   'e1_id': 2,
#   'e2_id': 0},
#  {'text': 'Meanwhile, <e1>Johnson</e1>  is under fire for his governments handling of an outbreak that has infected more than 200,000 <e2>Britons</e2> including the prime minister, who spent three nights in intensive care last month.',
#   'e1': 'Johnson',
#   'e2': 'Britons',
#   'e1_label': 'PERSON',
#   'e2_label': 'NORP',
#   'e1_id': 2,
#   'e2_id': 0},
#  {'text': 'Meanwhile, <e1>Johnson</e1>  is under fire for his governments handling of an outbreak that has infected more than 200,000 Britons including the prime minister, who spent <e2>three nights</e2> in intensive care last month.',
#   'e1': 'Johnson',
#   'e2': 'three nights',
#   'e1_label': 'PERSON',
#   'e2_label': 'DATE',
#   'e1_id': 2,
#   'e2_id': 0},
#  {'text': 'Meanwhile, <e1>Johnson</e1>  is under fire for his governments handling of an outbreak that has infected more than 200,000 Britons including the prime minister, who spent three nights in intensive care <e2>last month</e2>.',
#   'e1': 'Johnson',
#   'e2': 'last month',
#   'e1_label': 'PERSON',
#   'e2_label': 'DATE',
#   'e1_id': 2,
#   'e2_id': 1},
#  {'text': 'Meanwhile, Johnson is under fire for his governments handling of an outbreak that has infected <e1>more than 200,000</e1>  <e2>Britons</e2> including the prime minister, who spent three nights in intensive care last month.',
#   'e1': 'more than 200,000',
#   'e2': 'Britons',
#   'e1_label': 'CARDINAL',
#   'e2_label': 'NORP',
#   'e1_id': 0,
#   'e2_id': 0},
#  {'text': 'Meanwhile, Johnson is under fire for his governments handling of an outbreak that has infected <e1>more than 200,000</e1>  Britons including the prime minister, who spent <e2>three nights</e2> in intensive care last month.',
#   'e1': 'more than 200,000',
#   'e2': 'three nights',
#   'e1_label': 'CARDINAL',
#   'e2_label': 'DATE',
#   'e1_id': 0,
#   'e2_id': 0},
#  {'text': 'Meanwhile, Johnson is under fire for his governments handling of an outbreak that has infected <e1>more than 200,000</e1>  Britons including the prime minister, who spent three nights in intensive care <e2>last month</e2>.',
#   'e1': 'more than 200,000',
#   'e2': 'last month',
#   'e1_label': 'CARDINAL',
#   'e2_label': 'DATE',
#   'e1_id': 0,
#   'e2_id': 1},
#  {'text': 'Meanwhile, Johnson is under fire for his governments handling of an outbreak that has infected more than 200,000 <e1>Britons</e1>  including the prime minister, who spent <e2>three nights</e2> in intensive care last month.',
#   'e1': 'Britons',
#   'e2': 'three nights',
#   'e1_label': 'NORP',
#   'e2_label': 'DATE',
#   'e1_id': 0,
#   'e2_id': 0},
#  {'text': 'Meanwhile, Johnson is under fire for his governments handling of an outbreak that has infected more than 200,000 <e1>Britons</e1>  including the prime minister, who spent three nights in intensive care <e2>last month</e2>.',
#   'e1': 'Britons',
#   'e2': 'last month',
#   'e1_label': 'NORP',
#   'e2_label': 'DATE',
#   'e1_id': 0,
#   'e2_id': 1},
#  {'text': 'Meanwhile, Johnson is under fire for his governments handling of an outbreak that has infected more than 200,000 Britons including the prime minister, who spent <e1>three nights</e1>  in intensive care <e2>last month</e2>.',
#   'e1': 'three nights',
#   'e2': 'last month',
#   'e1_label': 'DATE',
#   'e2_label': 'DATE',
#   'e1_id': 0,
#   'e2_id': 1},
#  {'text': 'On <e1>Wednesday</e1> , the government announced <e2>600 million pounds ($735 million)</e2> in funding to stop coronavirus infections in nursing homes.',
#   'e1': 'Wednesday',
#   'e2': '600 million pounds ($735 million)',
#   'e1_label': 'DATE',
#   'e2_label': 'MONEY',
#   'e1_id': 2,
#   'e2_id': 0},
#  {'text': '<e1>More than 8,000</e1>  people with the coronavirus died in nursing homes up to <e2>the start of May</e2>, according to Britains Office for National Statistics, and the full figure is likely substantially higher.',
#   'e1': 'More than 8,000',
#   'e2': 'the start of May',
#   'e1_label': 'CARDINAL',
#   'e2_label': 'DATE',
#   'e1_id': 0,
#   'e2_id': 0},
#  {'text': '<e1>More than 8,000</e1>  people with the coronavirus died in nursing homes up to the start of May, according to <e2>Britains Office for National Statistics</e2>, and the full figure is likely substantially higher.',
#   'e1': 'More than 8,000',
#   'e2': 'Britains Office for National Statistics',
#   'e1_label': 'CARDINAL',
#   'e2_label': 'ORG',
#   'e1_id': 0,
#   'e2_id': 0},
#  {'text': 'More than 8,000 people with the coronavirus died in nursing homes up to <e1>the start of May</e1> , according to <e2>Britains Office for National Statistics</e2>, and the full figure is likely substantially higher.',
#   'e1': 'the start of May',
#   'e2': 'Britains Office for National Statistics',
#   'e1_label': 'DATE',
#   'e2_label': 'ORG',
#   'e1_id': 0,
#   'e2_id': 0},
#  {'text': '<e1>Keir Starmer</e1> , the leader of the opposition <e2>Labour Party</e2>, accused the government of being lax for releasing people from hospitals into nursing homes earlier in the outbreak without testing them for the coronavirus.',
#   'e1': 'Keir Starmer',
#   'e2': 'Labour Party',
#   'e1_label': 'PERSON',
#   'e2_label': 'ORG',
#   'e1_id': 0,
#   'e2_id': 0}]

# %%
generateTextToNer(raw)
# Out:
# {'text': 'LONDON The sound of crisply struck golf balls could be heard in England for the first time in nearly two months as courses reopened Wednesday, part of a modest easing of coronavirus lockdown restrictions. But delight at the resumption of some recreation was mixed with anxiety among commuters and transit staff as people began to return to workplaces. After seven weeks of lockdown, people in England were allowed to exercise more than once a day and with one person from outside their household, provided they remained 2 meters (around 6.5 feet) apart. Other sporting activities, such as tennis, fishing, boating and lake swimming, also resumed. David Baillie, the pro at Dulwich & Sydenham Hill Golf Club in southeast London, said 170 members booked tee-off times to play in pairs on Wednesday and that all slots are taken through Tuesday. It is gone swimmingly well, he said. Stores selling gardening supplies reported busy trade as they reopened, and potential home buyers were told they could once again visit properties. And, importantly in the context of getting the ailing British economy back on its feet, people who cannot work from home, such as those in construction and manufacturing, were being encouraged by the government to return to work if they can do so safely. Some construction sites have resumed work, and automaker Ford announced plans to restart production at two factories in the U.K. The easing of restrictions applies only in England. The semi-autonomous governments of Scotland, Wales and Northern Ireland are going more slowly and sticking with the Stay Home message, partly because the epidemic is at different stages in different parts of the country, Johnson justified the modest easing on the grounds that Britain has passed the peak of the outbreak, with deaths and new infections in decline. The U.K. has officially recorded the most coronavirus-related deaths in Europe, more than 33,000, a toll second only to the United States. The government is trying to defeat the outbreak while gradually restarting an economy that shrank by 2% in the first quarter of the year, with output falling 5.8% in March, the month everyday life began to shut down. Treasury chief Rishi Sunak said the U.K. was headed for a "significant recession. But there was confusion about the back to work guidance, first announced by U.K. Prime Minister Boris Johnson on Sunday. Critics of Johnsons Conservative government say the changes, spelled out in a 50-page document, are confusing and potentially dangerous. Johnson denied that there had been mixed messaging and told lawmakers that the common sense of the British people is shining through. One of the main concerns centers on how people can travel to work while keeping to social distancing requirements, especially in London, where most commuters use public transit. Transport for London said that in the morning hours up to 10 a.m., the number of passengers on the capitals subway system was around 7.3% higher than on the same day last week. Carl Moss, 39, traveling to his job as a gardener at St. Thomas Hospital in central London, said it is been busier today and that he would seen more office, finance-type people as well as manual workers. The union that represents train drivers voiced concerns about overcrowding following images on social media showing passengers crowded together on Tube trains and buses. At Londons Victoria train and subway station, worker Linda Freitas said she felt anxious and a bit scared about the prospect of more commuters. A ticket office worker at the station died with COVID-19 last month after being spat at by a man claiming to have the coronavirus. If its done gradually lets see, but if its too many people then it will be a bit of a problem," Freitas said. Meanwhile, Johnson is under fire for his governments handling of an outbreak that has infected more than 200,000 Britons including the prime minister, who spent three nights in intensive care last month. On Wednesday,  ...
#  'ents': [{'text': 'LONDON', 'id': 0, 'end': 6, 'start': 0, 'type': 'GPE'},
#   {'text': 'England', 'id': 0, 'end': 71, 'start': 64, 'type': 'GPE'},
#   {'text': 'first', 'id': 0, 'end': 85, 'start': 80, 'type': 'ORDINAL'},
#   {'text': 'nearly two months',
#    'id': 0,
#    'end': 111,
#    'start': 94,
#    'type': 'DATE'},
#   {'text': 'Wednesday', 'id': 0, 'end': 141, 'start': 132, 'type': 'DATE'},
#   {'text': 'seven weeks', 'id': 0, 'end': 369, 'start': 358, 'type': 'DATE'},
#   {'text': 'England', 'id': 1, 'end': 400, 'start': 393, 'type': 'GPE'},
#   {'text': 'one', 'id': 0, 'end': 459, 'start': 456, 'type': 'CARDINAL'},
#   {'text': '2 meters', 'id': 0, 'end': 528, 'start': 520, 'type': 'QUANTITY'},
#   {'text': 'around 6.5 feet',
#    'id': 0,
#    'end': 545,
#    'start': 530,
#    'type': 'QUANTITY'},
#   {'text': 'David Baillie',
#    'id': 0,
#    'end': 660,
#    'start': 647,
#    'type': 'PERSON'},
#   {'text': 'Dulwich & Sydenham Hill Golf Club',
#    'id': 0,
#    'end': 706,
#    'start': 673,
#    'type': 'ORG'},
#   {'text': 'London', 'id': 0, 'end': 726, 'start': 720, 'type': 'GPE'},
#   {'text': '170', 'id': 0, 'end': 736, 'start': 733, 'type': 'CARDINAL'},
#   {'text': 'Wednesday', 'id': 1, 'end': 795, 'start': 786, 'type': 'DATE'},
#   {'text': 'Tuesday', 'id': 0, 'end': 840, 'start': 833, 'type': 'DATE'},
#   {'text': 'British', 'id': 0, 'end': 1088, 'start': 1081, 'type': 'NORP'},
#   {'text': 'Ford', 'id': 0, 'end': 1343, 'start': 1339, 'type': 'ORG'},
#   {'text': 'two', 'id': 0, 'end': 1388, 'start': 1385, 'type': 'CARDINAL'},
#   {'text': 'U.K.', 'id': 0, 'end': 1410, 'start': 1406, 'type': 'GPE'},
#   {'text': 'England', 'id': 2, 'end': 1461, 'start': 1454, 'type': 'GPE'},
#   {'text': 'Scotland', 'id': 0, 'end': 1506, 'start': 1498, 'type': 'GPE'},
#   {'text': 'Wales', 'id': 0, 'end': 1513, 'start': 1508, 'type': 'GPE'},
#   {'text': 'Northern Ireland',
#    'id': 0,
#    'end': 1534,
#    'start': 1518,
#    'type': 'GPE'},
#   {'text': 'Johnson', 'id': 0, 'end': 1691, 'start': 1684, 'type': 'PERSON'},
#   {'text': 'Britain', 'id': 0, 'end': 1747, 'start': 1740, 'type': 'GPE'},
#   {'text': 'U.K.', 'id': 1, 'end': 1836, 'start': 1832, 'type': 'GPE'},
#   {'text': 'Europe', 'id': 0, 'end': 1906, 'start': 1900, 'type': 'LOC'},
#   {'text': 'more than 33,000',
#    'id': 0,
#    'end': 1924,
#    'start': 1908,
#    'type': 'CARDINAL'},
#   {'text': 'second', 'id': 0, 'end': 1939, 'start': 1933, 'type': 'ORDINAL'},
#   {'text': 'the United States',
#    'id': 0,
#    'end': 1965,
#    'start': 1948,
#    'type': 'GPE'},
#   {'text': '2%', 'id': 0, 'end': 2070, 'start': 2068, 'type': 'PERCENT'},
#   {'text': 'the first quarter of the year',
#    'id': 0,
#    'end': 2103,
#    'start': 2074,
#    'type': 'DATE'},
#   {'text': '5.8%', 'id': 0, 'end': 2129, 'start': 2125, 'type': 'PERCENT'},
#   {'text': 'March', 'id': 0, 'end': 2138, 'start': 2133, 'type': 'DATE'},
#   {'text': 'the month', 'id': 0, 'end': 2149, 'start': 2140, 'type': 'DATE'},
#   {'text': 'Treasury', 'id': 0, 'end': 2192, 'start': 2184, 'type': 'ORG'},
#   {'text': 'Rishi Sunak',
#    'id': 0,
#    'end': 2210,
#    'start': 2199,
#    'type': 'PERSON'},
#   {'text': 'U.K.', 'id': 2, 'end': 2224, 'start': 2220, 'type': 'GPE'},
#   {'text': 'U.K.', 'id': 3, 'end': 2346, 'start': 2342, 'type': 'GPE'},
#   {'text': 'Boris Johnson',
#    'id': 0,
#    'end': 2375,
#    'start': 2362,
#    'type': 'PERSON'},
#   {'text': 'Sunday', 'id': 0, 'end': 2385, 'start': 2379, 'type': 'DATE'},
#   {'text': 'Johnsons Conservative',
#    'id': 0,
#    'end': 2419,
#    'start': 2398,
#    'type': 'ORG'},
#   {'text': 'Johnson', 'id': 1, 'end': 2531, 'start': 2524, 'type': 'PERSON'},
#   {'text': 'British', 'id': 1, 'end': 2630, 'start': 2623, 'type': 'NORP'},
#   {'text': 'One', 'id': 0, 'end': 2661, 'start': 2658, 'type': 'CARDINAL'},
#   {'text': 'London', 'id': 1, 'end': 2793, 'start': 2787, 'type': 'GPE'},
#   {'text': 'Transport for London',
#    'id': 0,
#    'end': 2856,
#    'start': 2836,
#    'type': 'ORG'},
#   {'text': 'the morning hours',
#    'id': 0,
#    'end': 2887,
#    'start': 2870,
#    'type': 'TIME'},
#   {'text': 'up to 10 a.m.',
#    'id': 0,
#    'end': 2901,
#    'start': 2888,
#    'type': 'TIME'},
#   {'text': 'around 7.3%',
#    'id': 0,
#    'end': 2973,
#    'start': 2962,
#    'type': 'PERCENT'},
#   {'text': 'the same day last week',
#    'id': 0,
#    'end': 3011,
#    'start': 2989,
#    'type': 'DATE'},
#   {'text': 'Carl Moss', 'id': 0, 'end': 3022, 'start': 3013, 'type': 'PERSON'},
#   {'text': '39', 'id': 0, 'end': 3026, 'start': 3024, 'type': 'DATE'},
#   {'text': 'St. Thomas Hospital',
#    'id': 0,
#    'end': 3085,
#    'start': 3066,
#    'type': 'ORG'},
#   {'text': 'London', 'id': 2, 'end': 3103, 'start': 3097, 'type': 'GPE'},
#   {'text': 'today', 'id': 0, 'end': 3133, 'start': 3128, 'type': 'DATE'},
#   {'text': 'Londons Victoria',
#    'id': 0,
#    'end': 3406,
#    'start': 3390,
#    'type': 'ORG'},
#   {'text': 'Linda Freitas',
#    'id': 0,
#    'end': 3453,
#    'start': 3440,
#    'type': 'PERSON'},
#   {'text': 'COVID-19', 'id': 0, 'end': 3587, 'start': 3579, 'type': 'ORG'},
#   {'text': 'last month', 'id': 0, 'end': 3598, 'start': 3588, 'type': 'DATE'},
#   {'text': 'Freitas', 'id': 0, 'end': 3765, 'start': 3758, 'type': 'PERSON'},
#   {'text': 'Johnson', 'id': 2, 'end': 3790, 'start': 3783, 'type': 'PERSON'},
#   {'text': 'more than 200,000',
#    'id': 0,
#    'end': 3884,
#    'start': 3867,
#    'type': 'CARDINAL'},
#   {'text': 'Britons', 'id': 0, 'end': 3892, 'start': 3885, 'type': 'NORP'},
#   {'text': 'three nights',
#    'id': 0,
#    'end': 3945,
#    'start': 3933,
#    'type': 'DATE'},
#   {'text': 'last month', 'id': 1, 'end': 3974, 'start': 3964, 'type': 'DATE'},
#   {'text': 'Wednesday', 'id': 2, 'end': 3988, 'start': 3979, 'type': 'DATE'},
#   {'text': '600 million pounds ($735 million)',
#    'id': 0,
#    'end': 4048,
#    'start': 4015,
#    'type': 'MONEY'},
#   {'text': 'thousands',
#    'id': 0,
#    'end': 4168,
#    'start': 4159,
#    'type': 'CARDINAL'},
#   {'text': 'More than 8,000',
#    'id': 0,
#    'end': 4209,
#    'start': 4194,
#    'type': 'CARDINAL'},
#   {'text': 'the start of May',
#    'id': 0,
#    'end': 4282,
#    'start': 4266,
#    'type': 'DATE'},
#   {'text': 'Britains Office for National Statistics',
#    'id': 0,
#    'end': 4336,
#    'start': 4297,
#    'type': 'ORG'},
#   {'text': 'Keir Starmer',
#    'id': 0,
#    'end': 4402,
#    'start': 4390,
#    'type': 'PERSON'},
#   {'text': 'Labour Party', 'id': 0, 'end': 4445, 'start': 4433, 'type': 'ORG'},
#   {'text': 'Johnson', 'id': 3, 'end': 4611, 'start': 4604, 'type': 'PERSON'}]}
